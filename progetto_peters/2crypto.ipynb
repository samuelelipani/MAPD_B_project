# %% [markdown]
# ## 2-Cryptography
#
# Assume we receive an email from a friend of us sending the following encrypted message:
#
# **K]amua!trgpy**
#
# We are told how the encryption algorithm works, meaning that we know we need a key to decrypt the message and that there is a secret variable added for each ASCII character.
# <br> It follows that this kind of problem concerns **symmetric encryption**. Indeed:
# - there is just one key (symmetric key) used, and it is the same key exploited to encrypt and decrypt the message as we will see with the brute force approach in reconstructing the encryption and decryption procedure
# - key lengths are usually 128 or 256 bits, depending on the security criteria, in this case ASCII values range from 0 to 255 and their bits representation is in term of two "nibbles" meaning 8 bits
# - even if we have not the key shared from the addresser we can find the correct and only one by a dictionary approach trying all the possibile $[0,255]$ values
#
# Recall that in symmmetric encryption both sender and receiver know in a deterministic way how the cipher is made, in this case the only missing part is the key that however can be discovered.
#
# Let's try to find the correct key that manages to decrypt the above mentioned unknown text.

# %% [markdown]
# By using the unpacking operator in a string and by surrounding everything by square brackets we create a list of single characters that can be translated into their correspondent ASCII values through the `ord()` function

# %%
original_mess = [*"K]amua!trgpy"]
original_ascii = [ord(original_mess[i]) for i in range(len(original_mess))]
original_ascii
# Out:
# [75, 93, 97, 109, 117, 97, 33, 116, 114, 103, 112, 121]

# %% [markdown]
# As suggested by the sender, depending on the length of the message, a nonce variable is added to each ASCII value of the message in such a way that the first number is 5 for the firs value, the second is 6 for the second value and so on.

# %%
nonce = [i for i in range(5,5 + len(original_ascii))]

# %% [markdown]
# Without using the numpy library we could generate the resulting list of traslated ASCII numbers by doing another list comprehension. The sender indeed added, to make the message more secure, a nonce variable
# to each ASCII value of the cypher. Then in order to retrieve the cypher we subtract the nonce list from
# the original_ascii list

# %%
trasl_ascii = [original_ascii[i] - nonce[i] for i in range(len(nonce))]

# %% [markdown]
# In order to solve the problem we are opting for a dictionary approach. This means we are pairing keys with solutions proposal, trying all of them with `brute force` and choosing the one that leads to a meaningful phrase. First of all let's consider integer keys that range from 0 to 255. The encryption algorithm works by adding the key value to each `ASCII` character of the original message. It follows that we should subtract the same key for the purpose of retrieving the solution.

# %%
ascii = [i for i in range(256)]  
keym_dictionary = {}

for i in ascii:
    keym_dictionary[i] = [trasl_ascii[j] + i for j in range(len(trasl_ascii))]

# %% [markdown]
# By printing all the key-message pairs we notice that only one makes sense: as we are going to see it is the one corresponding to $key= \pm 10$ depending on ho we see the encryption algorithm.

# %%
for j in ascii: 
    print([chr(keym_dictionary[j][i]) for i in range(len(keym_dictionary[j]))], j)
# Out:
# ['F', 'W', 'Z', 'e', 'l', 'W', '\x16', 'h', 'e', 'Y', 'a', 'i'] 0
# ['G', 'X', '[', 'f', 'm', 'X', '\x17', 'i', 'f', 'Z', 'b', 'j'] 1
# ['H', 'Y', '\\', 'g', 'n', 'Y', '\x18', 'j', 'g', '[', 'c', 'k'] 2
# ['I', 'Z', ']', 'h', 'o', 'Z', '\x19', 'k', 'h', '\\', 'd', 'l'] 3
# ['J', '[', '^', 'i', 'p', '[', '\x1a', 'l', 'i', ']', 'e', 'm'] 4
# ['K', '\\', '_', 'j', 'q', '\\', '\x1b', 'm', 'j', '^', 'f', 'n'] 5
# ['L', ']', '`', 'k', 'r', ']', '\x1c', 'n', 'k', '_', 'g', 'o'] 6
# ['M', '^', 'a', 'l', 's', '^', '\x1d', 'o', 'l', '`', 'h', 'p'] 7
# ['N', '_', 'b', 'm', 't', '_', '\x1e', 'p', 'm', 'a', 'i', 'q'] 8
# ['O', '`', 'c', 'n', 'u', '`', '\x1f', 'q', 'n', 'b', 'j', 'r'] 9
# ['P', 'a', 'd', 'o', 'v', 'a', ' ', 'r', 'o', 'c', 'k', 's'] 10
# ['Q', 'b', 'e', 'p', 'w', 'b', '!', 's', 'p', 'd', 'l', 't'] 11
# ['R', 'c', 'f', 'q', 'x', 'c', '"', 't', 'q', 'e', 'm', 'u'] 12
# ['S', 'd', 'g', 'r', 'y', 'd', '#', 'u', 'r', 'f', 'n', 'v'] 13
# ['T', 'e', 'h', 's', 'z', 'e', '$', 'v', 's', 'g', 'o', 'w'] 14
# ['U', 'f', 'i', 't', '{', 'f', '%', 'w', 't', 'h', 'p', 'x'] 15
# ['V', 'g', 'j', 'u', '|', 'g', '&', 'x', 'u', 'i', 'q', 'y'] 16
# ['W', 'h', 'k', 'v', '}', 'h', "'", 'y', 'v', 'j', 'r', 'z'] 17
# ['X', 'i', 'l', 'w', '~', 'i', '(', 'z', 'w', 'k', 's', '{'] 18
# ['Y', 'j', 'm', 'x', '\x7f', 'j', ')', '{', 'x', 'l', 't', '|'] 19
# ['Z', 'k', 'n', 'y', '\x80', 'k', '*', '|', 'y', 'm', 'u', '}'] 20
# ['[', 'l', 'o', 'z', '\x81', 'l', '+', '}', 'z', 'n', 'v', '~'] 21
# ['\\', 'm', 'p', '{', '\x82', 'm', ',', '~', '{', 'o', 'w', '\x7f'] 22
# [']', 'n', 'q', '|', '\x83', 'n', '-', '\x7f', '|', 'p', 'x', '\x80'] 23
# ['^', 'o', 'r', '}', '\x84', 'o', '.', '\x80', '}', 'q', 'y', '\x81'] 24
# ['_', 'p', 's', '~', '\x85', 'p', '/', '\x81', '~', 'r', 'z', '\x82'] 25
# ['`', 'q', 't', '\x7f', '\x86', 'q', '0', '\x82', '\x7f', 's', '{', '\x83'] 26
# ['a', 'r', 'u', '\x80', '\x87', 'r', '1', '\x83', '\x80', 't', '|', '\x84'] 27
# ['b', 's', 'v', '\x81', '\x88', 's', '2', '\x84', '\x81', 'u', '}', '\x85'] 28
# ['c', 't', 'w', '\x82', '\x89', 't', '3', '\x85', '\x82', 'v', '~', '\x86'] 29
# ['d', 'u', 'x', '\x83', '\x8a', 'u', '4', '\x86', '\x83', 'w', '\x7f', '\x87'] 30
# ['e', 'v', 'y', '\x84', '\x8b', 'v', '5', '\x87', '\x84', 'x', '\x80', '\x88'] 31
# ['f', 'w', 'z', '\x85', '\x8c', 'w', '6', '\x88', '\x85', 'y', '\x81', '\x89'] 32
# ['g', 'x', '{', '\x86', '\x8d', 'x', '7', '\x89', '\x86', 'z', '\x82', '\x8a'] 33
# ['h', 'y', '|', '\x87', '\x8e', 'y', '8', '\x8a', '\x87', '{', '\x83', '\x8b'] 34
# ['i', 'z', '}', '\x88', '\x8f', 'z', '9', '\x8b', '\x88', '|', '\x84', '\x8c'] 35
# ['\x82', '\x93', '\x96', '¡', '¨', '\x93', 'R', '¤', '¡', '\x95', '\x9d', '¥'] 60
# ['\x83', '\x94', '\x97', '¢', '©', '\x94', 'S', '¥', '¢', '\x96', '\x9e', '¦'] 61
# ['\x84', '\x95', '\x98', '£', 'ª', '\x95', 'T', '¦', '£', '\x97', '\x9f', '§'] 62
# ['\x85', '\x96', '\x99', '¤', '«', '\x96', 'U', '§', '¤', '\x98', '\xa0', '¨'] 63
# ['\x86', '\x97', '\x9a', '¥', '¬', '\x97', 'V', '¨', '¥', '\x99', '¡', '©'] 64
# ['\x87', '\x98', '\x9b', '¦', '\xad', '\x98', 'W', '©', '¦', '\x9a', '¢', 'ª'] 65
# ['\x88', '\x99', '\x9c', '§', '®', '\x99', 'X', 'ª', '§', '\x9b', '£', '«'] 66
# ['\x89', '\x9a', '\x9d', '¨', '¯', '\x9a', 'Y', '«', '¨', '\x9c', '¤', '¬'] 67
# ['\x8a', '\x9b', '\x9e', '©', '°', '\x9b', 'Z', '¬', '©', '\x9d', '¥', '\xad'] 68
# ['\x8b', '\x9c', '\x9f', 'ª', '±', '\x9c', '[', '\xad', 'ª', '\x9e', '¦', '®'] 69
# ['\x8c', '\x9d', '\xa0', '«', '²', '\x9d', '\\', '®', '«', '\x9f', '§', '¯'] 70
# ['\x8d', '\x9e', '¡', '¬', '³', '\x9e', ']', '¯', '¬', '\xa0', '¨', '°'] 71
# ['\x8e', '\x9f', '¢', '\xad', '´', '\x9f', '^', '°', '\xad', '¡', '©', '±'] 72
# ['\x8f', '\xa0', '£', '®', 'µ', '\xa0', '_', '±', '®', '¢', 'ª', '²'] 73
# ['\x90', '¡', '¤', '¯', '¶', '¡', '`', '²', '¯', '£', '«', '³'] 74
# ['\x91', '¢', '¥', '°', '·', '¢', 'a', '³', '°', '¤', '¬', '´'] 75
# ['\x92', '£', '¦', '±', '¸', '£', 'b', '´', '±', '¥', '\xad', 'µ'] 76
# ['\x93', '¤', '§', '²', '¹', '¤', 'c', 'µ', '²', '¦', '®', '¶'] 77
# ['\x94', '¥', '¨', '³', 'º', '¥', 'd', '¶', '³', '§', '¯', '·'] 78
# ['\x95', '¦', '©', '´', '»', '¦', 'e', '·', '´', '¨', '°', '¸'] 79
# ['\x96', '§', 'ª', 'µ', '¼', '§', 'f', '¸', 'µ', '©', '±', '¹'] 80
# ['\x97', '¨', '«', '¶', '½', '¨', 'g', '¹', '¶', 'ª', '²', 'º'] 81
# ['\x98', '©', '¬', '·', '¾', '©', 'h', 'º', '·', '«', '³', '»'] 82
# ['\x99', 'ª', '\xad', '¸', '¿', 'ª', 'i', '»', '¸', '¬', '´', '¼'] 83
# ['\x9a', '«', '®', '¹', 'À', '«', 'j', '¼', '¹', '\xad', 'µ', '½'] 84
# ['\x9b', '¬', '¯', 'º', 'Á', '¬', 'k', '½', 'º', '®', '¶', '¾'] 85
# ['\x9c', '\xad', '°', '»', 'Â', '\xad', 'l', '¾', '»', '¯', '·', '¿'] 86
# ['\x9d', '®', '±', '¼', 'Ã', '®', 'm', '¿', '¼', '°', '¸', 'À'] 87
# ['\x9e', '¯', '²', '½', 'Ä', '¯', 'n', 'À', '½', '±', '¹', 'Á'] 88
# ['\x9f', '°', '³', '¾', 'Å', '°', 'o', 'Á', '¾', '²', 'º', 'Â'] 89
# ['\xa0', '±', '´', '¿', 'Æ', '±', 'p', 'Â', '¿', '³', '»', 'Ã'] 90
# ['¡', '²', 'µ', 'À', 'Ç', '²', 'q', 'Ã', 'À', '´', '¼', 'Ä'] 91
# ['¢', '³', '¶', 'Á', 'È', '³', 'r', 'Ä', 'Á', 'µ', '½', 'Å'] 92
# ['£', '´', '·', 'Â', 'É', '´', 's', 'Å', 'Â', '¶', '¾', 'Æ'] 93
# ['¤', 'µ', '¸', 'Ã', 'Ê', 'µ', 't', 'Æ', 'Ã', '·', '¿', 'Ç'] 94
# ['¥', '¶', '¹', 'Ä', 'Ë', '¶', 'u', 'Ç', 'Ä', '¸', 'À', 'È'] 95
# ['¦', '·', 'º', 'Å', 'Ì', '·', 'v', 'È', 'Å', '¹', 'Á', 'É'] 96
# ['§', '¸', '»', 'Æ', 'Í', '¸', 'w', 'É', 'Æ', 'º', 'Â', 'Ê'] 97
# ['¨', '¹', '¼', 'Ç', 'Î', '¹', 'x', 'Ê', 'Ç', '»', 'Ã', 'Ë'] 98
# ['©', 'º', '½', 'È', 'Ï', 'º', 'y', 'Ë', 'È', '¼', 'Ä', 'Ì'] 99
# ['ª', '»', '¾', 'É', 'Ð', '»', 'z', 'Ì', 'É', '½', 'Å', 'Í'] 100
# ['«', '¼', '¿', 'Ê', 'Ñ', '¼', '{', 'Í', 'Ê', '¾', 'Æ', 'Î'] 101
# ['¬', '½', 'À', 'Ë', 'Ò', '½', '|', 'Î', 'Ë', '¿', 'Ç', 'Ï'] 102
# ['\xad', '¾', 'Á', 'Ì', 'Ó', '¾', '}', 'Ï', 'Ì', 'À', 'È', 'Ð'] 103
# ['®', '¿', 'Â', 'Í', 'Ô', '¿', '~', 'Ð', 'Í', 'Á', 'É', 'Ñ'] 104
# ['¯', 'À', 'Ã', 'Î', 'Õ', 'À', '\x7f', 'Ñ', 'Î', 'Â', 'Ê', 'Ò'] 105
# ['°', 'Á', 'Ä', 'Ï', 'Ö', 'Á', '\x80', 'Ò', 'Ï', 'Ã', 'Ë', 'Ó'] 106
# ['±', 'Â', 'Å', 'Ð', '×', 'Â', '\x81', 'Ó', 'Ð', 'Ä', 'Ì', 'Ô'] 107
# ['²', 'Ã', 'Æ', 'Ñ', 'Ø', 'Ã', '\x82', 'Ô', 'Ñ', 'Å', 'Í', 'Õ'] 108
# ['³', 'Ä', 'Ç', 'Ò', 'Ù', 'Ä', '\x83', 'Õ', 'Ò', 'Æ', 'Î', 'Ö'] 109
# ['´', 'Å', 'È', 'Ó', 'Ú', 'Å', '\x84', 'Ö', 'Ó', 'Ç', 'Ï', '×'] 110
# ['µ', 'Æ', 'É', 'Ô', 'Û', 'Æ', '\x85', '×', 'Ô', 'È', 'Ð', 'Ø'] 111
# ['¶', 'Ç', 'Ê', 'Õ', 'Ü', 'Ç', '\x86', 'Ø', 'Õ', 'É', 'Ñ', 'Ù'] 112
# ['·', 'È', 'Ë', 'Ö', 'Ý', 'È', '\x87', 'Ù', 'Ö', 'Ê', 'Ò', 'Ú'] 113
# ['¸', 'É', 'Ì', '×', 'Þ', 'É', '\x88', 'Ú', '×', 'Ë', 'Ó', 'Û'] 114
# ['¹', 'Ê', 'Í', 'Ø', 'ß', 'Ê', '\x89', 'Û', 'Ø', 'Ì', 'Ô', 'Ü'] 115
# ['º', 'Ë', 'Î', 'Ù', 'à', 'Ë', '\x8a', 'Ü', 'Ù', 'Í', 'Õ', 'Ý'] 116
# ['»', 'Ì', 'Ï', 'Ú', 'á', 'Ì', '\x8b', 'Ý', 'Ú', 'Î', 'Ö', 'Þ'] 117
# ['¼', 'Í', 'Ð', 'Û', 'â', 'Í', '\x8c', 'Þ', 'Û', 'Ï', '×', 'ß'] 118
# ['½', 'Î', 'Ñ', 'Ü', 'ã', 'Î', '\x8d', 'ß', 'Ü', 'Ð', 'Ø', 'à'] 119
# ['¾', 'Ï', 'Ò', 'Ý', 'ä', 'Ï', '\x8e', 'à', 'Ý', 'Ñ', 'Ù', 'á'] 120
# ['¿', 'Ð', 'Ó', 'Þ', 'å', 'Ð', '\x8f', 'á', 'Þ', 'Ò', 'Ú', 'â'] 121
# ['À', 'Ñ', 'Ô', 'ß', 'æ', 'Ñ', '\x90', 'â', 'ß', 'Ó', 'Û', 'ã'] 122
# ['Á', 'Ò', 'Õ', 'à', 'ç', 'Ò', '\x91', 'ã', 'à', 'Ô', 'Ü', 'ä'] 123
# ['Â', 'Ó', 'Ö', 'á', 'è', 'Ó', '\x92', 'ä', 'á', 'Õ', 'Ý', 'å'] 124
# ['Ã', 'Ô', '×', 'â', 'é', 'Ô', '\x93', 'å', 'â', 'Ö', 'Þ', 'æ'] 125
# ['Ä', 'Õ', 'Ø', 'ã', 'ê', 'Õ', '\x94', 'æ', 'ã', '×', 'ß', 'ç'] 126
# ['Å', 'Ö', 'Ù', 'ä', 'ë', 'Ö', '\x95', 'ç', 'ä', 'Ø', 'à', 'è'] 127
# ['Æ', '×', 'Ú', 'å', 'ì', '×', '\x96', 'è', 'å', 'Ù', 'á', 'é'] 128
# ['Ç', 'Ø', 'Û', 'æ', 'í', 'Ø', '\x97', 'é', 'æ', 'Ú', 'â', 'ê'] 129
# ['È', 'Ù', 'Ü', 'ç', 'î', 'Ù', '\x98', 'ê', 'ç', 'Û', 'ã', 'ë'] 130
# ['É', 'Ú', 'Ý', 'è', 'ï', 'Ú', '\x99', 'ë', 'è', 'Ü', 'ä', 'ì'] 131
# ['Ê', 'Û', 'Þ', 'é', 'ð', 'Û', '\x9a', 'ì', 'é', 'Ý', 'å', 'í'] 132
# ['Ë', 'Ü', 'ß', 'ê', 'ñ', 'Ü', '\x9b', 'í', 'ê', 'Þ', 'æ', 'î'] 133
# ['Ì', 'Ý', 'à', 'ë', 'ò', 'Ý', '\x9c', 'î', 'ë', 'ß', 'ç', 'ï'] 134
# ['Í', 'Þ', 'á', 'ì', 'ó', 'Þ', '\x9d', 'ï', 'ì', 'à', 'è', 'ð'] 135
# ['ç', 'ø', 'û', 'Ć', 'č', 'ø', '·', 'ĉ', 'Ć', 'ú', 'Ă', 'Ċ'] 161
# ['è', 'ù', 'ü', 'ć', 'Ď', 'ù', '¸', 'Ċ', 'ć', 'û', 'ă', 'ċ'] 162
# ['é', 'ú', 'ý', 'Ĉ', 'ď', 'ú', '¹', 'ċ', 'Ĉ', 'ü', 'Ą', 'Č'] 163
# ['ê', 'û', 'þ', 'ĉ', 'Đ', 'û', 'º', 'Č', 'ĉ', 'ý', 'ą', 'č'] 164
# ['ë', 'ü', 'ÿ', 'Ċ', 'đ', 'ü', '»', 'č', 'Ċ', 'þ', 'Ć', 'Ď'] 165
# ['ì', 'ý', 'Ā', 'ċ', 'Ē', 'ý', '¼', 'Ď', 'ċ', 'ÿ', 'ć', 'ď'] 166
# ['í', 'þ', 'ā', 'Č', 'ē', 'þ', '½', 'ď', 'Č', 'Ā', 'Ĉ', 'Đ'] 167
# ['î', 'ÿ', 'Ă', 'č', 'Ĕ', 'ÿ', '¾', 'Đ', 'č', 'ā', 'ĉ', 'đ'] 168
# ['ï', 'Ā', 'ă', 'Ď', 'ĕ', 'Ā', '¿', 'đ', 'Ď', 'Ă', 'Ċ', 'Ē'] 169
# ['ð', 'ā', 'Ą', 'ď', 'Ė', 'ā', 'À', 'Ē', 'ď', 'ă', 'ċ', 'ē'] 170
# ['ñ', 'Ă', 'ą', 'Đ', 'ė', 'Ă', 'Á', 'ē', 'Đ', 'Ą', 'Č', 'Ĕ'] 171
# ['ò', 'ă', 'Ć', 'đ', 'Ę', 'ă', 'Â', 'Ĕ', 'đ', 'ą', 'č', 'ĕ'] 172
# ['ó', 'Ą', 'ć', 'Ē', 'ę', 'Ą', 'Ã', 'ĕ', 'Ē', 'Ć', 'Ď', 'Ė'] 173
# ['ô', 'ą', 'Ĉ', 'ē', 'Ě', 'ą', 'Ä', 'Ė', 'ē', 'ć', 'ď', 'ė'] 174
# ['õ', 'Ć', 'ĉ', 'Ĕ', 'ě', 'Ć', 'Å', 'ė', 'Ĕ', 'Ĉ', 'Đ', 'Ę'] 175
# ['ö', 'ć', 'Ċ', 'ĕ', 'Ĝ', 'ć', 'Æ', 'Ę', 'ĕ', 'ĉ', 'đ', 'ę'] 176
# ['÷', 'Ĉ', 'ċ', 'Ė', 'ĝ', 'Ĉ', 'Ç', 'ę', 'Ė', 'Ċ', 'Ē', 'Ě'] 177
# ['ø', 'ĉ', 'Č', 'ė', 'Ğ', 'ĉ', 'È', 'Ě', 'ė', 'ċ', 'ē', 'ě'] 178
# ['ù', 'Ċ', 'č', 'Ę', 'ğ', 'Ċ', 'É', 'ě', 'Ę', 'Č', 'Ĕ', 'Ĝ'] 179
# ['ú', 'ċ', 'Ď', 'ę', 'Ġ', 'ċ', 'Ê', 'Ĝ', 'ę', 'č', 'ĕ', 'ĝ'] 180
# ['û', 'Č', 'ď', 'Ě', 'ġ', 'Č', 'Ë', 'ĝ', 'Ě', 'Ď', 'Ė', 'Ğ'] 181
# ['ü', 'č', 'Đ', 'ě', 'Ģ', 'č', 'Ì', 'Ğ', 'ě', 'ď', 'ė', 'ğ'] 182
# ['ý', 'Ď', 'đ', 'Ĝ', 'ģ', 'Ď', 'Í', 'ğ', 'Ĝ', 'Đ', 'Ę', 'Ġ'] 183
# ['þ', 'ď', 'Ē', 'ĝ', 'Ĥ', 'ď', 'Î', 'Ġ', 'ĝ', 'đ', 'ę', 'ġ'] 184
# ['ÿ', 'Đ', 'ē', 'Ğ', 'ĥ', 'Đ', 'Ï', 'ġ', 'Ğ', 'Ē', 'Ě', 'Ģ'] 185
# ['Ā', 'đ', 'Ĕ', 'ğ', 'Ħ', 'đ', 'Ð', 'Ģ', 'ğ', 'ē', 'ě', 'ģ'] 186
# ['ā', 'Ē', 'ĕ', 'Ġ', 'ħ', 'Ē', 'Ñ', 'ģ', 'Ġ', 'Ĕ', 'Ĝ', 'Ĥ'] 187
# ['Ă', 'ē', 'Ė', 'ġ', 'Ĩ', 'ē', 'Ò', 'Ĥ', 'ġ', 'ĕ', 'ĝ', 'ĥ'] 188
# ['ă', 'Ĕ', 'ė', 'Ģ', 'ĩ', 'Ĕ', 'Ó', 'ĥ', 'Ģ', 'Ė', 'Ğ', 'Ħ'] 189
# ['Ą', 'ĕ', 'Ę', 'ģ', 'Ī', 'ĕ', 'Ô', 'Ħ', 'ģ', 'ė', 'ğ', 'ħ'] 190
# ['ą', 'Ė', 'ę', 'Ĥ', 'ī', 'Ė', 'Õ', 'ħ', 'Ĥ', 'Ę', 'Ġ', 'Ĩ'] 191
# ['Ć', 'ė', 'Ě', 'ĥ', 'Ĭ', 'ė', 'Ö', 'Ĩ', 'ĥ', 'ę', 'ġ', 'ĩ'] 192
# ['ć', 'Ę', 'ě', 'Ħ', 'ĭ', 'Ę', '×', 'ĩ', 'Ħ', 'Ě', 'Ģ', 'Ī'] 193
# ['Ĉ', 'ę', 'Ĝ', 'ħ', 'Į', 'ę', 'Ø', 'Ī', 'ħ', 'ě', 'ģ', 'ī'] 194
# ['ĉ', 'Ě', 'ĝ', 'Ĩ', 'į', 'Ě', 'Ù', 'ī', 'Ĩ', 'Ĝ', 'Ĥ', 'Ĭ'] 195
# ['Ċ', 'ě', 'Ğ', 'ĩ', 'İ', 'ě', 'Ú', 'Ĭ', 'ĩ', 'ĝ', 'ĥ', 'ĭ'] 196
# ['ċ', 'Ĝ', 'ğ', 'Ī', 'ı', 'Ĝ', 'Û', 'ĭ', 'Ī', 'Ğ', 'Ħ', 'Į'] 197
# ['Č', 'ĝ', 'Ġ', 'ī', 'Ĳ', 'ĝ', 'Ü', 'Į', 'ī', 'ğ', 'ħ', 'į'] 198
# ['č', 'Ğ', 'ġ', 'Ĭ', 'ĳ', 'Ğ', 'Ý', 'į', 'Ĭ', 'Ġ', 'Ĩ', 'İ'] 199
# ['Ď', 'ğ', 'Ģ', 'ĭ', 'Ĵ', 'ğ', 'Þ', 'İ', 'ĭ', 'ġ', 'ĩ', 'ı'] 200
# ['ď', 'Ġ', 'ģ', 'Į', 'ĵ', 'Ġ', 'ß', 'ı', 'Į', 'Ģ', 'Ī', 'Ĳ'] 201
# ['ķ', 'ň', 'ŋ', 'Ŗ', 'ŝ', 'ň', 'ć', 'ř', 'Ŗ', 'Ŋ', 'Œ', 'Ś'] 241
# ['ĸ', 'ŉ', 'Ō', 'ŗ', 'Ş', 'ŉ', 'Ĉ', 'Ś', 'ŗ', 'ŋ', 'œ', 'ś'] 242
# ['Ĺ', 'Ŋ', 'ō', 'Ř', 'ş', 'Ŋ', 'ĉ', 'ś', 'Ř', 'Ō', 'Ŕ', 'Ŝ'] 243
# ['ĺ', 'ŋ', 'Ŏ', 'ř', 'Š', 'ŋ', 'Ċ', 'Ŝ', 'ř', 'ō', 'ŕ', 'ŝ'] 244
# ['Ļ', 'Ō', 'ŏ', 'Ś', 'š', 'Ō', 'ċ', 'ŝ', 'Ś', 'Ŏ', 'Ŗ', 'Ş'] 245
# ['ļ', 'ō', 'Ő', 'ś', 'Ţ', 'ō', 'Č', 'Ş', 'ś', 'ŏ', 'ŗ', 'ş'] 246
# ['Ľ', 'Ŏ', 'ő', 'Ŝ', 'ţ', 'Ŏ', 'č', 'ş', 'Ŝ', 'Ő', 'Ř', 'Š'] 247
# ['ľ', 'ŏ', 'Œ', 'ŝ', 'Ť', 'ŏ', 'Ď', 'Š', 'ŝ', 'ő', 'ř', 'š'] 248
# ['Ŀ', 'Ő', 'œ', 'Ş', 'ť', 'Ő', 'ď', 'š', 'Ş', 'Œ', 'Ś', 'Ţ'] 249
# ['ŀ', 'ő', 'Ŕ', 'ş', 'Ŧ', 'ő', 'Đ', 'Ţ', 'ş', 'œ', 'ś', 'ţ'] 250
# ['Ł', 'Œ', 'ŕ', 'Š', 'ŧ', 'Œ', 'đ', 'ţ', 'Š', 'Ŕ', 'Ŝ', 'Ť'] 251
# ['ł', 'œ', 'Ŗ', 'š', 'Ũ', 'œ', 'Ē', 'Ť', 'š', 'ŕ', 'ŝ', 'ť'] 252
# ['Ń', 'Ŕ', 'ŗ', 'Ţ', 'ũ', 'Ŕ', 'ē', 'ť', 'Ţ', 'Ŗ', 'Ş', 'Ŧ'] 253
# ['ń', 'ŕ', 'Ř', 'ţ', 'Ū', 'ŕ', 'Ĕ', 'Ŧ', 'ţ', 'ŗ', 'ş', 'ŧ'] 254
# ['Ņ', 'Ŗ', 'ř', 'Ť', 'ū', 'Ŗ', 'ĕ', 'ŧ', 'Ť', 'Ř', 'Š', 'Ũ'] 255

# %% [markdown]
# The original message was therefore:

# %%
message = [chr(keym_dictionary[10][i]) for i in range(len(keym_dictionary[10]))]
"".join(message)
# Out:
# 'Padova rocks'

# %% [markdown]
# #### Encryption procedure
#
# We could try, in order to show one of the property of symmetric encryption, that given the key and the original message we can rebuild the cyphred one by reversing the decryption procedure:
# <br> what changes are the signs of the key and the `nonce` variable!

# %%
backwords = [ord(message[i]) for i in range(len(message))]
backwords = [backwords[i] - 10 for i in range(len(backwords))]
nonce_back = [i for i in range(5,5 + len(backwords))]
backwords = [backwords[i] + nonce_back[i] for i in range(len(backwords))]
init = [chr(backwords[i]) for i in range(len(backwords))]
"".join(init)
# Out:
# 'K]amua!trgpy'
